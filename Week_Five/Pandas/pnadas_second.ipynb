# %%
import pandas as pd

# %% [markdown]
# # Dataframe from python dictionary

# %%
data_dictionary = {
    'Name': ['A', 'Gita', 'Hari' ,'C','D','E','F'],
    'Age': [10, 25, 20 ,30,40,50,60],
    'Address' : ['Pokhara','das','sad','sada','sadsad','sdsd','sadsasd']
}
df_dict = pd.DataFrame(data_dictionary)
df_dict
# Out:
#    Name  Age  Address
# 0     A   10  Pokhara
# 1  Gita   25      das
# 2  Hari   20      sad
# 3     C   30     sada
# 4     D   40   sadsad
# 5     E   50     sdsd
# 6     F   60  sadsasd

# %%
data_dictionary_list = [{'Name' : "Sandy" , 'Age' : 20 , "Address" : 'Syangja'},
                   {'Name' : "B" , 'Age' : 20 , "Address" : 'Syangja'},
                   {'Name' : "C" , 'Age' : 22 , "Address" : 'Pokhara'},
                   {'Name' : "C" , 'Age' : 24 , "Address" : 'Bakthapur'},
                   {'Name' : "D" , 'Age' : 26 , "Address" : 'Kathmandu'},
                   {'Name' : "E" , 'Age' : 28 , "Address" : 'Khahare'},
                   {'Name' : "E" , 'Age' : 21 , "Address" : 'Palpa'},
                   ]
data_dict_list = pd.DataFrame(data_dictionary_list)
data_dict_list
# Out:
#     Name  Age    Address
# 0  Sandy   20    Syangja
# 1      B   20    Syangja
# 2      C   22    Pokhara
# 3      C   24  Bakthapur
# 4      D   26  Kathmandu
# 5      E   28    Khahare
# 6      E   21      Palpa

# %%
data_tuple = (
    ('Apple', 25, 'Kathmandu'),
    ('Ball', 30, 'Bhaktapur'),
    ('Cat', 35, 'Nepal'),
    ('Dog' , 40 , 'India'),
    ('Egg' , 50 , 'France'),
    ('Fish' , 55,'USA'),
    ('Gun' , 40,'Finland')
)
df_tuple = pd.DataFrame(data_tuple, columns=['Name', 'Age', 'Address'])
df_tuple
# Out:
#     Name  Age    Address
# 0  Apple   25  Kathmandu
# 1   Ball   30  Bhaktapur
# 2    Cat   35      Nepal
# 3    Dog   40      India
# 4    Egg   50     France
# 5   Fish   55        USA
# 6    Gun   40    Finland

# %%
data_list_list = [["Helo", 20 , 'Bhaktapur'],
                  ["Good", 40,"Syangja"],
                  ["Good_Bye", 60,"Pokhara"],
                  ["New", 22 , 'Bhaktapur'],
                  ["Say", 44,"Syangja"],
                  ["_Bye", 62,"Pokhara"],
                  ["Man", 41,"Syangja"],
                  ]

df_list_list = pd.DataFrame(data_list_list, columns=['Name', 'Age' , 'Address'])
df_list_list
# Out:
#        Name  Age    Address
# 0      Helo   20  Bhaktapur
# 1      Good   40    Syangja
# 2  Good_Bye   60    Pokhara
# 3       New   22  Bhaktapur
# 4       Say   44    Syangja
# 5      _Bye   62    Pokhara
# 6       Man   41    Syangja

# %% [markdown]
# <!-- Data CSV Read -->

# %%
# df_weather = pd.read_csv('Data/weather_data.csv')
# df_weather => Throws Error
# Task One
import csv as csv
data_file = open('Data/weather_data.csv' , 'r')
csv_file = csv.reader(data_file)
list_data = list(csv_file)
df_weather = pd.DataFrame(list_data[3:] , columns=list_data[2])
df_weather
# print(df)
# Out:
#           day    temperature     windspeed     event
# 0    1/1/2017             32             6      Rain
# 1    1/4/2017  not available             9     Sunny
# 2    1/5/2017             -1  not measured      Snow
# 3    1/6/2017  not available             7  no event
# 4    1/7/2017             32  not measured      Rain
# 5    1/8/2017  not available  not measured     Sunny
# 6    1/9/2017  not available  not measured  no event
# 7   1/10/2017             34             8    Cloudy
# 8   1/11/2017             -4            -1      Snow
# 9   1/12/2017             26            12     Sunny
# 10  1/13/2017             12            12     Rainy
# 11  1/11/2017             -1            12      Snow
# 12  1/14/2017             40            -1     Sunny

# %%
# Advance Try
file_path = "Data/imports-85.data"
import_columns = ['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration', 'num_of_doors',
          'body_style', 'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width', 
           'height', 'curb_weight', 'engine_type', 'num_of_cylinders', 'engine_size', 'fuel_system',
          'bore', 'stroke', 'compression', 'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 
           'price']
# print(import_columns)

from csv import reader
file_path = "Data/imports-85.data"

csv_ = open(file_path, "r") 
    
csv_reader = csv.reader(csv_)
pd.DataFrame(csv_reader , columns=import_columns)

# csv_.close()
# Out:
#     symboling normalized_losses         make fuel_type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas        std
# 201        -1                95        volvo       gas      turbo
# 202        -1                95        volvo       gas        std
# 203        -1                95        volvo    diesel      turbo
# 204        -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location wheel_base  ...  \
# 0            two  convertible          rwd           front      88.60  ...
# ...

# %%
# Task 2
file_path = 'Data/imports-85.data'
file_open = open(file_path , 'r')
csv_data = csv.reader(file_open)
list_data_  = list(csv_data)
# print(list_data_)
pd.DataFrame(list_data_ , columns=import_columns)
# Out:
# [['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd', 'front', '88.60', '168.80', '64.10', '48.80', '2548', 'dohc', 'four', '130', 'mpfi', '3.47', '2.68', '9.00', '111', '5000', '21', '27', '13495'], ['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd', 'front', '88.60', '168.80', '64.10', '48.80', '2548', 'dohc', 'four', '130', 'mpfi', '3.47', '2.68', '9.00', '111', '5000', '21', '27', '16500'], ['1', '?', 'alfa-romero', 'gas', 'std', 'two', 'hatchback', 'rwd', 'front', '94.50', '171.20', '65.50', '52.40', '2823', 'ohcv', 'six', '152', 'mpfi', '2.68', '3.47', '9.00', '154', '5000', '19', '26', '16500'], ['2', '164', 'audi', 'gas', 'std', 'four', 'sedan', 'fwd', 'front', '99.80', '176.60', '66.20', '54.30', '2337', 'ohc', 'four', '109', 'mpfi', '3.19', '3.40', '10.00', '102', '5500', '24', '30', '13950'], ['2', '164', 'audi', 'gas', 'std', 'four', 'sedan', '4wd', 'front', '99.40', '176.60', '66.40', '54.30', '2824', 'ohc', 'five', '136', 'mpfi', '3.19',
# ...

# %%
df_weather = pd.read_csv("Data/weather_data.csv", skiprows=1)
df_weather
# Out:
#                                       asdsadfs
# day       temperature   windspeed        event
# 1/1/2017  32            6                 Rain
# 1/4/2017  not available 9                Sunny
# 1/5/2017  -1            not measured      Snow
# 1/6/2017  not available 7             no event
# 1/7/2017  32            not measured      Rain
# 1/8/2017  not available not measured     Sunny
# 1/9/2017  not available not measured  no event
# 1/10/2017 34            8               Cloudy
# 1/11/2017 -4            -1                Snow
# 1/12/2017 26            12               Sunny
# 1/13/2017 12            12               Rainy
# 1/11/2017 -1            12                Snow
# 1/14/2017 40            -1               Sunny

# %%
df_weather = pd.read_csv("Data/weather_data.csv", header=2)
df_weather
# Out:
#           day    temperature     windspeed     event
# 0    1/1/2017             32             6      Rain
# 1    1/4/2017  not available             9     Sunny
# 2    1/5/2017             -1  not measured      Snow
# 3    1/6/2017  not available             7  no event
# 4    1/7/2017             32  not measured      Rain
# 5    1/8/2017  not available  not measured     Sunny
# 6    1/9/2017  not available  not measured  no event
# 7   1/10/2017             34             8    Cloudy
# 8   1/11/2017             -4            -1      Snow
# 9   1/12/2017             26            12     Sunny
# 10  1/13/2017             12            12     Rainy
# 11  1/11/2017             -1            12      Snow
# 12  1/14/2017             40            -1     Sunny
